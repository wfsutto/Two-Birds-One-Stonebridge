# %% [markdown]
# # Seasonal + Lag Analysis of Oil, Gas, and Brine Production
# # Using well distances + quarterly production

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import geopandas as gpd
from shapely.geometry import Point

plt.style.use('seaborn-v0_8')

# %% [markdown]
# ### Load Data

# %%
# Load well information
well_info = pd.read_csv('../data/final/well_information_final.csv')

# Load permit list (includes SWIW wells)
permits = pd.read_csv('../data/final/permit_plug_list_final.csv')

# Load nearest saltwater distances
nearest_saltwater = pd.read_csv('../data/distance/well_to_nearest_saltwater_updated.csv')

# Load quarterly production (your combined production dataset)
quarterly_prod = pd.read_csv('../data/final/quarterly_production_final.csv')

# %% [markdown]
# ### Prepare the Dataset

# %%
# Merge production with distances
df = quarterly_prod.merge(
    nearest_saltwater[['API WELL NUMBER', 'Nearest_SWIW_km']],
    left_on='API Number',
    right_on='API WELL NUMBER',
    how='left'
)

# %% [markdown]
# ### Add Seasonal Indicators

# %%
# Fix quarter column (convert to number)
df['Quarter'] = pd.to_numeric(df['Quarter (1, 2, 3, 4, n/a)'], errors='coerce')

# Year from production year column
df['Year'] = df['Production Year']

# Map quarters to seasons
season_map = {1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Fall'}
df['Season'] = df['Quarter'].map(season_map)

# %% [markdown]
# ### Seasonal Production Patterns (Statewide)

# %%
# Compute seasonal averages
seasonal_summary = (
    df.groupby(['Season'])[['Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)']]
      .mean()
      .reindex(['Winter', 'Spring', 'Summer', 'Fall'])
)

# Oil
seasonal_summary[['Oil (Bbls)']].plot(
    kind='bar',
    figsize=(10,6),
    color='firebrick'
)
plt.title("Seasonal Average Oil Production (Statewide)")
plt.ylabel("Average Volume")
plt.show()

# Gas
seasonal_summary[['Gas (Mcf)']].plot(
    kind='bar',
    figsize=(10,6),
    color='royalblue'
)
plt.title("Seasonal Average Gas Production (Statewide)")
plt.ylabel("Average Volume")
plt.show()

# Brine
seasonal_summary[['Brine (Bbls)']].plot(
    kind='bar',
    figsize=(10,6),
    color='seagreen'
)
plt.title("Seasonal Average Brine Production (Statewide)")
plt.ylabel("Average Volume")
plt.show()

# %% [markdown]
# ### Seasonal Patterns by Distance-to-SWIW Group

# %%
bins = [0, 1, 5, 10, 20, 1000]
labels = ['0–1 km', '1–5 km', '5–10 km', '10–20 km', '20+ km']

df['SWIW_Distance_Group'] = pd.cut(
    df['Nearest_SWIW_km'],
    bins=bins,
    labels=labels,
    include_lowest=True
)

plt.figure(figsize=(10,6))
sns.lineplot(
    data=df, 
    x='Season', 
    y='Oil (Bbls)', 
    hue='SWIW_Distance_Group',
    estimator='mean',
    ci=None
)
plt.title("Seasonal Oil Production by Distance to Nearest SWIW")
plt.ylabel("Mean Oil Production")
plt.show()
# Out:
# /var/folders/1b/y_w2tt4s36scl8nlg9t_mnw40000gn/T/ipykernel_7977/3519007374.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %% [markdown]
# ### Prepare Data for Lag Analysis

# %%
df['Quarter'] = df['Quarter (1, 2, 3, 4, n/a)'].replace('n/a', pd.NA).astype(float)

# Create Period String
df['Period'] = (
    df['Production Year'].astype(int).astype(str)
    + 'Q'
    + df['Quarter'].fillna(1).astype(int).astype(str)
)
df['DATE'] = pd.PeriodIndex(df['Period'], freq='Q').to_timestamp()

df = df.sort_values(['API Number', 'DATE'])

df['DATE'] = pd.PeriodIndex(df['Period'], freq='Q').to_timestamp()
df['Oil_lag1']  = df.groupby('API Number')['Oil (Bbls)'].shift(1)   # one quarter
df['Oil_lag4']  = df.groupby('API Number')['Oil (Bbls)'].shift(4)   # one year
df['Oil_lag8']  = df.groupby('API Number')['Oil (Bbls)'].shift(8)   # two years
df['Oil_lag12'] = df.groupby('API Number')['Oil (Bbls)'].shift(12)  # three years

# %% [markdown]
# ### Lag Regression

# %%
import statsmodels.api as sm

lag_df = df.dropna(subset=[
    'Oil (Bbls)', 
    'Oil_lag1', 
    'Oil_lag4', 
    'Oil_lag8', 
    'Oil_lag12',
    'Nearest_SWIW_km'
])

X1 = lag_df[['Oil_lag1', 'Nearest_SWIW_km']]
X1 = sm.add_constant(X1)
y  = lag_df['Oil (Bbls)']

model1 = sm.OLS(y, X1).fit()
print("\n===== LAG-1 MODEL =====")
print(model1.summary())
# Out:
# ===== LAG-1 MODEL =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Oil (Bbls)   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                 1.402e+05
# Date:                Sat, 22 Nov 2025   Prob (F-statistic):               0.00
# Time:                        10:15:30   Log-Likelihood:            -5.1907e+05
# No. Observations:               66604   AIC:                         1.038e+06
# Df Residuals:                   66601   BIC:                         1.038e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              89.3732      5.428     16.467      0.000      78.735     100.011
# Oil_lag1            0.8319      0.002    526.561      0.000       0.829       0.835
# Nearest_SWIW_km    -2.3161      0.410     -5.651      0.000      -3.120      -1.513
# ==============================================================================
# Omnibus:                    98179.774   Durbin-Watson:                   2.363
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4620246440.890
# Skew:                           7.395   Prob(JB):                         0.00
# Kurtosis:                    1293.207   Cond. No.                     3.76e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.76e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X4 = lag_df[['Oil_lag4', 'Nearest_SWIW_km']]
X4 = sm.add_constant(X4)

model4 = sm.OLS(y, X4).fit()
print("\n===== LAG-4 MODEL =====")
print(model4.summary())
# Out:
# ===== LAG-4 MODEL =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Oil (Bbls)   R-squared:                       0.728
# Model:                            OLS   Adj. R-squared:                  0.728
# Method:                 Least Squares   F-statistic:                 8.906e+04
# Date:                Sat, 22 Nov 2025   Prob (F-statistic):               0.00
# Time:                        10:15:30   Log-Likelihood:            -5.3071e+05
# No. Observations:               66604   AIC:                         1.061e+06
# Df Residuals:                   66601   BIC:                         1.061e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             133.0752      6.460     20.599      0.000     120.413     145.738
# Oil_lag4            0.6100      0.001    419.368      0.000       0.607       0.613
# Nearest_SWIW_km    -2.7970      0.488     -5.728      0.000      -3.754      -1.840
# ==============================================================================
# Omnibus:                   104276.273   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        839042925.808
# Skew:                           9.006   Prob(JB):                         0.00
# Kurtosis:                     552.559   Cond. No.                     4.84e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.84e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X8 = lag_df[['Oil_lag8', 'Nearest_SWIW_km']]
X8 = sm.add_constant(X8)

model8 = sm.OLS(y, X8).fit()
print("\n===== LAG-8 MODEL =====")
print(model8.summary())
# Out:
# ===== LAG-8 MODEL =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Oil (Bbls)   R-squared:                       0.656
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                 6.338e+04
# Date:                Sat, 22 Nov 2025   Prob (F-statistic):               0.00
# Time:                        10:15:30   Log-Likelihood:            -5.3855e+05
# No. Observations:               66604   AIC:                         1.077e+06
# Df Residuals:                   66601   BIC:                         1.077e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             219.5784      7.232     30.361      0.000     205.403     233.754
# Oil_lag8            0.3321      0.001    353.530      0.000       0.330       0.334
# Nearest_SWIW_km    -3.7329      0.549     -6.795      0.000      -4.810      -2.656
# ==============================================================================
# Omnibus:                    98874.475   Durbin-Watson:                   0.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        346134932.178
# Skew:                           8.280   Prob(JB):                         0.00
# Kurtosis:                     355.777   Cond. No.                     8.26e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X12 = lag_df[['Oil_lag12', 'Nearest_SWIW_km']]
X12 = sm.add_constant(X12)

model12 = sm.OLS(y, X12).fit()
print("\n===== LAG-12 MODEL =====")
print(model12.summary())
# Out:
# ===== LAG-12 MODEL =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Oil (Bbls)   R-squared:                       0.472
# Model:                            OLS   Adj. R-squared:                  0.472
# Method:                 Least Squares   F-statistic:                 2.978e+04
# Date:                Sat, 22 Nov 2025   Prob (F-statistic):               0.00
# Time:                        10:15:30   Log-Likelihood:            -5.5277e+05
# No. Observations:               66604   AIC:                         1.106e+06
# Df Residuals:                   66601   BIC:                         1.106e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             382.6546      8.889     43.046      0.000     365.231     400.078
# Oil_lag12           0.1155      0.000    241.680      0.000       0.115       0.116
# Nearest_SWIW_km    -8.1837      0.679    -12.044      0.000      -9.515      -6.852
# ==============================================================================
# Omnibus:                    86669.153   Durbin-Watson:                   0.817
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         82548246.291
# Skew:                           6.687   Prob(JB):                         0.00
# Kurtosis:                     174.949   Cond. No.                     1.96e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.96e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Combined Models

# %%
Xall = lag_df[['Oil_lag1','Oil_lag4','Oil_lag8','Oil_lag12','Nearest_SWIW_km']]
Xall = sm.add_constant(Xall)

combined_model = sm.OLS(y, Xall).fit()
print("\n===== COMBINED MODEL (LAG 1, 4, 8, 12) =====")
print(combined_model.summary())

comparison_table = pd.DataFrame({
    "Model": ["Lag 1","Lag 4","Lag 8","Lag 12","Combined"],
    "R_squared": [
        model1.rsquared,
        model4.rsquared,
        model8.rsquared,
        model12.rsquared,
        combined_model.rsquared
    ],
    "AIC": [
        model1.aic,
        model4.aic,
        model8.aic,
        model12.aic,
        combined_model.aic
    ],
    "Lag_Coefficient": [
        model1.params['Oil_lag1'],
        model4.params['Oil_lag4'],
        model8.params['Oil_lag8'],
        model12.params['Oil_lag12'],
        None 
    ],
    "Lag_SE": [
        model1.bse['Oil_lag1'],
        model4.bse['Oil_lag4'],
        model8.bse['Oil_lag8'],
        model12.bse['Oil_lag12'],
        None
    ]
})

print("\n===== MODEL COMPARISON TABLE =====")
print(comparison_table)
# Out:
# ===== COMBINED MODEL (LAG 1, 4, 8, 12) =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Oil (Bbls)   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                 6.662e+04
# Date:                Sat, 22 Nov 2025   Prob (F-statistic):               0.00
# Time:                        10:15:30   Log-Likelihood:            -5.1437e+05
# No. Observations:               66604   AIC:                         1.029e+06
# Df Residuals:                   66598   BIC:                         1.029e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              54.9026      5.070     10.830      0.000      44.966      64.839
# Oil_lag1            0.5653      0.003    186.201      0.000       0.559       0.571
# Oil_lag4            0.1705      0.003     62.282      0.000       0.165       0.176
# Oil_lag8            0.0351      0.002     23.256      0.000       0.032       0.038
# Oil_lag12           0.0030      0.000      6.854      0.000       0.002       0.004
# Nearest_SWIW_km    -0.8704      0.382     -2.277      0.023      -1.620      -0.121
# ==============================================================================
# Omnibus:                   130193.136   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4315766837.871
# Skew:                          14.488   Prob(JB):                         0.00
# Kurtosis:                    1249.715   Cond. No.                     2.16e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.16e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ===== MODEL COMPARISON TABLE =====
#       Model  R_squared           AIC  Lag_Coefficient    Lag_SE
# 0     Lag 1   0.808097  1.038154e+06         0.831881  0.001580
# 1     Lag 4   0.727847  1.061424e+06         0.609953  0.001454
# 2     Lag 8   0.655562  1.077112e+06         0.332050  0.000939
# 3    Lag 12   0.472131  1.105548e+06         0.115529  0.000478
# 4  Combined   0.833369  1.028755e+06              NaN       NaN

# %%
plot_df = comparison_table.dropna(subset=['Lag_Coefficient']).copy()
plot_df['Lag'] = [1,4,8,12]

plt.figure(figsize=(8,5))
plt.errorbar(
    plot_df['Lag'],
    plot_df['Lag_Coefficient'],
    yerr=plot_df['Lag_SE'],
    fmt='-o',
    capsize=5
)
plt.title("Effect of Lag Length on Coefficient Size")
plt.xlabel("Lag (quarters)")
plt.ylabel("Coefficient on Lagged Oil Production")
plt.grid(alpha=0.3)
plt.show()
